# %%
import os
import random
import cv2
import matplotlib.pyplot as plt

# ============================
# 1. DATASET PATH
# ============================

dataset_path = "/home/ravjot/datasets/Pomegranate Diseases Dataset"

# ============================
# 2. GET CLASS FOLDERS
# ============================

classes = os.listdir(dataset_path)

# ============================
# 3. DISPLAY 5 IMAGES PER CLASS
# ============================

for cls in classes:

    class_path = os.path.join(dataset_path, cls)

    if not os.path.isdir(class_path):
        continue

    images = os.listdir(class_path)

    # Randomly pick 5 images
    sample_images = random.sample(images, 5)

    plt.figure(figsize=(10, 2))

    for i, img_name in enumerate(sample_images):

        img_path = os.path.join(class_path, img_name)

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        plt.subplot(1, 5, i+1)
        plt.imshow(img)
        plt.title(cls)
        plt.axis("off")

    plt.suptitle(f"Sample Images - {cls}", fontsize=5)
    plt.show()

# %%
output_folder = "sample_outputs"
os.makedirs(output_folder, exist_ok=True)

plt.savefig(f"{output_folder}/{cls}.png")
